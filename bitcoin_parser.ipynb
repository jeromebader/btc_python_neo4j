# %% [markdown]
# ### BTC to NEO4J

# %% [markdown]
# ### Import libs and credentials

# %%
from bitcoinrpc.authproxy import AuthServiceProxy, JSONRPCException
import json
import itertools
import pandas as pd
import time
from neo4j import GraphDatabase
import pyarrow.parquet as pq
import numpy as np
import os

# %%
secrets_file = ".secrets/credentials.json"

with open(secrets_file, "r") as file:
    credentials = json.load(file)


# Bitcoin RPC connection
rpc_user = credentials["BitcoinRPC"]["rpc_user"]
rpc_password = credentials["BitcoinRPC"]["rpc_password"]

# Neo4j connection
username = credentials["Neo4j"]["username"]
password = credentials["Neo4j"]["password"]

# %% [markdown]
# ### RPC credetials - consider btc.config

# %%
# Setup Bitcoin RPC connection
rpc_user = rpc_user
rpc_password = rpc_password
rpc_host = "localhost"
rpc_port = "8332"
rpc_connection = AuthServiceProxy(f"http://{rpc_user}:{rpc_password}@{rpc_host}:{rpc_port}")

# %% [markdown]
# ### Neo4J local credentials

# %%
# Neo4j connection
uri = "bolt://localhost:7687" 
# username = "tester"      # 
# password = "testusxxx"

# %% [markdown]
# ### Parsing function from RPC Bitcoin core and writing to parquet

# %%
def process_chunk(start, end):
    '''
    Function for reading, parsing and writing from the BTC RPC

    Args:

        start: (int) Blocknumber start
        end: (int) Blocknumber end
    
    '''

    start_time = time.time()  
    output_dir = "blocks"

    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
  


    results_in = []
    results_out = []
    for b in range(start, end):
        blockhash = rpc_connection.getblockhash(b)
        block = rpc_connection.getblock(blockhash)

        for txid in block['tx']:
            raw_tx = rpc_connection.getrawtransaction(txid, 1, blockhash)
            tiempo = raw_tx['time']
            transactionid = raw_tx['txid']

            for i, vin in enumerate(raw_tx['vin']):
                try:
                    in_n = vin['vout']
                    vin_tx = rpc_connection.getrawtransaction(vin['txid'], 1)
                    in_vout = vin_tx['vout'][in_n]
                    in_value = in_vout['value']
                    in_address = in_vout['scriptPubKey']['address']
                    in_type = in_vout['scriptPubKey']['type']
                    in_asm = in_vout['scriptPubKey']['asm']

                    results_in.append({"tx":transactionid,"address_in": in_address,"input_pos":i, "value_in": in_value, "time":tiempo})
                except:
                    pass

            for vout_out in raw_tx['vout']:
                try:
                    out_n = vout_out['n']
                    out_value = vout_out['value']
                    out_address = vout_out['scriptPubKey']['address']
                    out_type = vout_out['scriptPubKey']['type']
                    out_asm = vout_out['scriptPubKey']['asm']

                    results_out.append({"tx":transactionid,"address_out": out_address,"output_pos":out_n, "value_out": out_value, "time":tiempo})
                except:
                    pass

    results_total = results_in + results_out
    df_export = pd.DataFrame(results_total)
    df_export.to_parquet(f'{output_dir}/export_blok_{start}_to_{end}.parquet',engine="pyarrow")

    end_time = time.time()  
    print(f"Processed block {start} to {end} in {end_time - start_time} seconds")

    # Save the last processed block number
    with open(f"{output_dir}/last_processed_block.txt", "w") as file:
        #file.write(str(end))
        file.write(f"{blockStart}, {chunk_size}, {end}")

    




# # Read the last processed block number from a file
# try:
#     with open("last_processed_block.txt", "r") as file:
#         blockStart = int(file.read())
# except FileNotFoundError:
#     pass  


output_dir = "blocks"

try:
    with open(f"{output_dir}/last_processed_block.txt", "r") as file:
        content = file.read()
        parts = content.split(', ')
        blockStart = int(parts[2])
except:
    pass
   

print('Blockstart',blockStart)

##### Start Parsing
#blockStart = 111000
blockLimit = 116000
chunk_size = 1000  # Define your chunk size here

#blockStart = blockStart+1

# Process the blockchain in chunks
try:
    for i in range(blockStart, blockLimit, chunk_size):
        process_chunk(i, min(i + chunk_size, blockLimit))
except KeyboardInterrupt:
    print("CTL+C, resume later")
# Out:
# Blockstart 113000
# Processed block 113000 to 114000 in 42.19905114173889 seconds
# Processed block 114000 to 115000 in 69.95119500160217 seconds
# Processed block 115000 to 116000 in 95.35189366340637 seconds

# %% [markdown]
# ### Import to NEO4J

# %%
# with open(f"export_blok_{blockStart}_to_{blockLimit}.txt", 'w+') as f:
#     df_string = df_export.to_string(header=False, index=False)
#     f.write(df_string)

# f.close()

# %% [markdown]
# #### Creating neo4j connection

# %%
driver = GraphDatabase.driver(uri, auth=(username, password))
session = driver.session(database="testdb")  ### change name of Neo4J database

# %% [markdown]
# ### Importing files

# %%
# Without function
# df_import = pd.read_parquet(f"export_blok_{blockStart}_to_{blockLimit}.parquet")
# df_sort = df_import.sort_values(by=['tx'],ascending=False)
# df_sort.replace(to_replace=[None], value=np.nan, inplace=True)
# df = df_sort


## reading chunks
#Old
# def read_chunk(blockStart, blockEnd):
#     df_import = pd.read_parquet(f"export_blok_{blockStart}_to_{blockEnd}.parquet")
#     df_sort = df_import.sort_values(by=['tx'],ascending=False)
#     df_sort.replace(to_replace=[None], value=np.nan, inplace=True)
#     df = df_sort
#     return df

# %% [markdown]
# ##### Reading based on chunksize

# %%
def read_chunks(blockStart, blockEnd, chunk_size):
    dfs = []
    output_dir = "blocks"
    for i in range(blockStart, blockEnd, chunk_size):
        start = i
        end = min(i + chunk_size, blockEnd)
        df = pd.read_parquet(f"{output_dir}/export_blok_{start}_to_{end}.parquet")
        dfs.append(df)
    return pd.concat(dfs, ignore_index=True)

# %%
# blockStart = 105000
# blockEnd = 110000
# chunk_size = 1000

# df = read_chunks(blockStart, blockEnd, chunk_size)

# %% [markdown]
# ### Create pd.Serie of the unique addresses

# %%
def address_transformation (df):
    addresses = pd.concat([df["address_in"], df["address_out"]]).drop_duplicates()
    return addresses

# %% [markdown]
# ### Create the tx format for writing to neo4j

# %%
# OLD
# def tx_ftransformation0 (df):

#     # unique transaction IDs
#     transaction_ids = df["tx"].dropna().unique()


#     transactions = []

#     # Iterate over the transaction IDs
#     for transaction_id in transaction_ids:
#         # Filter the DataFrame for the current transaction ID
#         df_transaction = df[df["tx"] == transaction_id]

#         # Extract the inputs
#         inputs = []
#         df_inputs = df_transaction.dropna(subset=["address_in"])
#         for _, row in df_inputs.iterrows():
#             address = row["address_in"]
#             amount = row["value_in"]
#             if pd.notnull(address) and pd.notnull(amount):
#                 inputs.append({"address": address, "amount": amount})

#         # Calculate the total amount
#         total_amount = sum([float(input_data["amount"]) for input_data in inputs])

#         #### COMPARING INPUT vs OUTPUT Sum ... difference are fees

#         # Extract the outputs
#         outputs = []
#         df_outputs = df_transaction.dropna(subset=["address_out"])
#         for _, row in df_outputs.iterrows():
#             address = row["address_out"]
#             amount = row["value_out"]
#             if pd.notnull(address) and pd.notnull(amount):
#                 outputs.append({"address": address, "amount": amount})

#         # Create the transaction dictionary
#         transaction_data = {
#             "transaction_id": transaction_id,
#             "total_amount": total_amount,
#             "inputs": inputs,
#             "outputs": outputs
#         }

#         transactions.append(transaction_data)
        
#     return transactions

# %%
def tx_ftransformation(df):
    # Unique transaction IDs
    transaction_ids = df["tx"].dropna().unique()

    transactions = []

    # Iterate over the transaction IDs
    for transaction_id in transaction_ids:
        # Filter the DataFrame for the current transaction ID
        df_transaction = df[df["tx"] == transaction_id]

        # Extract the inputs
        inputs = []
        df_inputs = df_transaction.dropna(subset=["address_in"])
        for _, row in df_inputs.iterrows():
            address = row["address_in"]
            amount = row["value_in"]
            time = row["time"]  # Added the 'time' field for inputs
            if pd.notnull(address) and pd.notnull(amount):
                inputs.append({"address": address, "amount": amount, "time": time})

        # Calculate the total amount
        total_amount = sum([float(input_data["amount"]) for input_data in inputs])

        # Extract the outputs
        outputs = []
        df_outputs = df_transaction.dropna(subset=["address_out"])
        for _, row in df_outputs.iterrows():
            address = row["address_out"]
            amount = row["value_out"]
            time = row["time"]  # Added the 'time' field for outputs
            if pd.notnull(address) and pd.notnull(amount):
                outputs.append({"address": address, "amount": amount, "time": time})

        # Create the transaction dictionary
        transaction_data = {
            "transaction_id": transaction_id,
            "total_amount": total_amount,
            "inputs": inputs,
            "outputs": outputs
        }

        transactions.append(transaction_data)

    return transactions

# %% [markdown]
# ### Write to Neo4J

# %%
# # Create unique constraint on Address nodes
# session.run("CREATE CONSTRAINT IF NOT EXISTS ON (a:Address) ASSERT a.address IS UNIQUE")
# session.run("CREATE CONSTRAINT IF NOT EXISTS ON (t:Transaction) ASSERT t.transaction_id IS UNIQUE")

# # Filter out null addresses
# filtered_addresses = addresses.dropna()

# # Create the Address nodes
# for address in filtered_addresses:
#     session.run(
#         """
#         MERGE (:Address {address: $address})
#         """,
#         address=address
#     )

# # Create the transaction nodes and relationships
# for transaction in transactions:
#     transaction_id = transaction["transaction_id"]
#     total_amount = transaction["total_amount"]
#     inputs = transaction["inputs"]
#     outputs = transaction["outputs"]
    
#     # Create the Transaction node
#     session.run(
#         """
#         CREATE (t:Transaction {transaction_id: $transaction_id, total_amount: $total_amount})
#         """,
#         transaction_id=transaction_id,
#         total_amount=total_amount
#     )
    
#     # Create the input relationships with individual amounts
#     for input_data in inputs:
#         input_address = input_data["address"]
#         input_amount = float(input_data["amount"])  # Convert amount to float
        
#         session.run(address_transformation
#             MATCH (a:Address {address: $input_address})
#             MATCH (t:Transaction {transaction_id: $transaction_id})
#             MERGE (a)-[:TRANSACTION_INPUT {amount: $input_amount}]->(t)
#             """,
#             input_address=input_address,
#             transaction_id=transaction_id,
#             input_amount=input_amount
#         )
    
#     # Create the output relationships with individual amounts
#     for output_data in outputs:
#         output_address = output_data["address"]
#         output_amount = float(output_data["amount"])  # Convert amount to float
        
#         session.run(
#             """
#             MATCH (a:Address {address: $output_address})
#             MATCH (t:Transaction {transaction_id: $transaction_id})
#             MERGE (t)-[:TRANSACTION_OUTPUT {amount: $output_amount}]->(a)
#             """,
#             output_address=output_address,
#             transaction_id=transaction_id,
#             output_amount=output_amount
#         )

# %%
## OLD

# def write_to_neo0 (session, addresses, transactions):

#     # Create unique constraint on Address nodes
#     session.run("CREATE CONSTRAINT IF NOT EXISTS ON (a:Address) ASSERT a.address IS UNIQUE")
#     session.run("CREATE CONSTRAINT IF NOT EXISTS ON (t:Transaction) ASSERT t.transaction_id IS UNIQUE")

#     filtered_addresses = addresses.dropna()
#     # Create the Address nodes
#     for address in filtered_addresses:
#         session.run(
#             """
#             MERGE (:Address {address: $address})
#             """,
#             address=address
#         )

#     # Create the transaction nodes and relationships
#     for transaction in transactions:
#         transaction_id = transaction["transaction_id"]
#         total_amount = transaction["total_amount"]
#         inputs = transaction["inputs"]
#         outputs = transaction["outputs"]
        
#         # Check if the Transaction node already exists
#         result = session.run(
#             """
#             MATCH (t:Transaction {transaction_id: $transaction_id})
#             RETURN count(t) AS count
#             """,
#             transaction_id=transaction_id
#         )
        
#         count = result.single()["count"]
        
#         if count == 0:
#             # Create the Transaction node
#             session.run(
#                 """
#                 CREATE (t:Transaction {transaction_id: $transaction_id, total_amount: $total_amount})
#                 """,
#                 transaction_id=transaction_id,
#                 total_amount=total_amount
#             )
        
#         # Create the input relationships with individual amounts
#         for input_data in inputs:
#             input_address = input_data["address"]
            
#             input_amount = float(input_data["amount"])  

#             session.run(
#                 """
#                 MATCH (a:Address {address: $input_address})
#                 MATCH (t:Transaction {transaction_id: $transaction_id})
#                 MERGE (a)-[:TRANSACTION_INPUT {amount: $input_amount}]->(t)
#                 """,
#                 input_address=input_address,
#                 transaction_id=transaction_id,
#                 input_amount=input_amount
#             )
        
#         # Create the output relationships 
#         for output_data in outputs:
#             output_address = output_data["address"]

#             output_amount = float(output_data["amount"])  
#             output_time = 
            
#             session.run(
#                 """
#                 MATCH (a:Address {address: $output_address})
#                 MATCH (t:Transaction {transaction_id: $transaction_id})
#                 MERGE (t)-[:TRANSACTION_OUTPUT {amount: $output_amount}]->(a)
#                 """,
#                 output_address=output_address,
#                 transaction_id=transaction_id,
#                 output_amount=output_amount
#             )

#     return True

# %%
from datetime import datetime

def write_to_neo(session, addresses, transactions):

    # Create unique constraint on Address nodes
    session.run("CREATE CONSTRAINT IF NOT EXISTS ON (a:Address) ASSERT a.address IS UNIQUE")
    session.run("CREATE CONSTRAINT IF NOT EXISTS ON (t:Transaction) ASSERT t.transaction_id IS UNIQUE")

    filtered_addresses = addresses.dropna()
    # Create the Address nodes
    for address in filtered_addresses:
        session.run(
            """
            MERGE (:Address {address: $address})
            """,
            address=address
        )

    # Create the transaction nodes and relationships
    for transaction in transactions:
        transaction_id = transaction["transaction_id"]
        total_amount = transaction["total_amount"]
        inputs = transaction["inputs"]
        outputs = transaction["outputs"]
        
        # Check if the Transaction node already exists
        result = session.run(
            """
            MATCH (t:Transaction {transaction_id: $transaction_id})
            RETURN count(t) AS count
            """,
            transaction_id=transaction_id
        )
        
        count = result.single()["count"]
        
        if count == 0:
            # Create the Transaction node
            session.run(
                """
                CREATE (t:Transaction {transaction_id: $transaction_id, total_amount: $total_amount})
                """,
                transaction_id=transaction_id,
                total_amount=total_amount
            )
        
        # Create the input relationships with individual amounts and time
        for input_data in inputs:
            input_address = input_data["address"]
            input_amount = float(input_data["amount"])
            input_time = input_data["time"]
            
            session.run(
                """
                MATCH (a:Address {address: $input_address})
                MATCH (t:Transaction {transaction_id: $transaction_id})
                MERGE (a)-[:TRANSACTION_INPUT {amount: $input_amount, time: $input_time}]->(t)
                """,
                input_address=input_address,
                transaction_id=transaction_id,
                input_amount=input_amount,
                input_time=input_time
            )
        
        # Create the output relationships with individual amounts and time
        for output_data in outputs:
            output_address = output_data["address"]
            output_amount = float(output_data["amount"])
            output_time = output_data["time"]  # Convert timestamp to human-readable time
            
            session.run(
                """
                MATCH (a:Address {address: $output_address})
                MATCH (t:Transaction {transaction_id: $transaction_id})
                MERGE (t)-[:TRANSACTION_OUTPUT {amount: $output_amount, time: $output_time}]->(a)
                """,
                output_address=output_address,
                transaction_id=transaction_id,
                output_amount=output_amount,
                output_time=output_time
            )

    return True

# %% [markdown]
# ### Complete flow writing Neo4j

# %%
# blockStart = 104001
# blockEnd = 105000
#df = read_chunk(blockStart, blockEnd)

##Processed block 112000 to 113000 in 25.98978304862976 seconds
##Processed block 113000 to 114000 in 43.11733293533325 seconds
##

blockStart = 113000
blockEnd = 116000
chunk_size = 1000

df = read_chunks(blockStart, blockEnd, chunk_size)

addresses = address_transformation(df)
transactions = tx_ftransformation(df)

# %%
transactions
# Out:
# [{'transaction_id': '69bfa9995a2e587e6b16e3d0292b79f5ab0cfe50ceb1bfbd80a0d30888c733e7',
#   'total_amount': 6.0,
#   'inputs': [{'address': '15mbsahyyG8UUPeX8BgAzntXgbbpDSCvKd',
#     'amount': Decimal('6.00000000'),
#     'time': 1299335141}],
#   'outputs': [{'address': '1CLb2Xhd6Bmw9iX44iSdVzSoGxyyDBB7Bq',
#     'amount': Decimal('4.00000000'),
#     'time': 1299335141},
#    {'address': '197knBpk846nki3R51rUCUAeLobKngKsVe',
#     'amount': Decimal('2.00000000'),
#     'time': 1299335141}]},
#  {'transaction_id': '23c6e93f53b42de620ea663b151c9651802cc9dbf30f575f5dd4891eec80386c',
#   'total_amount': 79.29,
#   'inputs': [{'address': '1CAmvuizVuANavWSvAYqxypfTKFxz2cSPg',
#     'amount': Decimal('79.29000000'),
#     'time': 1299335141}],
#   'outputs': [{'address': '16KADGbf7Lna9T3ohk8rGw5V418Xqv3krh',
#     'amount': Decimal('79.23000000'),
#     'time': 1299335141},
#    {'address': '1C7QAuYEpXLWbVbtgD9EDY2khtNqdHe7V4',
#     'amount': Decimal('0.05000000'),
#     'time': 1299335141}]},
#  {'transaction_id': '846067070c45b8de8e30b676dd8491accb6a4987e629d80e4a23798f2a4f4b88',
#   'total_amount': 79.23,
#   'inputs': [{'address': '16KADGbf7Lna9T3ohk8rGw5V418Xqv3krh',
#     'amount': Decimal('79.23000000'),
#     'time': 1299335141}],
#   'outputs': [{'address': '1HyHGJjUvsbpr4DX6nrA2EYyXyZqiysLGq',
#     'amount': Decimal('0.05000000'),
#     'time': 1299335141},
#    {'address': '19zzW2b2odPWPmX8m4Y3zgakUWHEEUf5Kk',
#     'amount': Decimal('79.17000000'),
#     'time': 1299335141}]},
#  {'transaction_id': '19f4273b6d5bed678a6a8a225ec8b16838428e7a785a20db880b8bcfb56d75ee',
#   'total_amount': 79.17,
#   'inputs': [{'address': '19zzW2b2odPWPmX8m4Y3zgakUWHEEUf5Kk',
#     'amount': Decimal('79.17000000'),
#     'time': 1299335141}],
#   'outputs': [{'address': '19HY4dPZVLepSSviawjRbBwYiP329HnvpX',
#     'amount': Decimal('79.11000000'),
#     'time': 1299335141},
#    {'address': '1AMDRkiztByS9bBdtoaoihfQtB9FQy87Fy',
#     'amount': Decimal('0.05000000'),
#     'time': 1299335141}]},
#  {'transaction_id': 'a82882d74e52a7f2c99fde01e3c667854f9c8fb6b3632ccc03f247ccacbc05c0',
#   'total_amount': 79.11,
#   'inputs': [{'address': '19HY4dPZVLepSSviawjRbBwYiP329HnvpX',
#     'amount': Decimal('79.11000000'),
#     'time': 1299335141}],
#   'outputs': [{'address': '1GRJ3FTyfzpoBt7Qi7D3bYakCKcz6X8x4p',
#     'amount': Decimal('0.05000000'),
#     'time': 1299335141},
#    {'address': '1FKoyq946cv6XNqnmMoqrfCnbbzqBK2mto',
#     'amount': Decimal('79.05000000'),
#     'time': 1299335141}]},
#  {'transaction_id': '32ca4cd290ba7f9c228fd8e7b55eb8adfdb91cf7b2ef7647c536a603967137d8',
#   'total_amount': 79.05,
#   'inputs': [{'address': '1FKoyq946cv6XNqnmMoqrfCnbbzqBK2mto',
#     'amount': Decimal('79.05000000'),
#     'time': 1299335141}],
#   'outputs': [{'address': '1377qgkbevqaKbAKmYat6EktidAo6r2K2t',
#     'amount': Decimal('0.05000000'),
#     'time': 1299335141},
#    {'address': '1D93VKrgSynXT4NZ79mNEwFCS7N9YErZ7F',
#     'amount': Decimal('78.99000000'),
#     'time': 1299335141}]},
#  {'transaction_id': '5d5b91f488c5e8a420165758bdf809c8df91d0e4c2003a841317711aee764659',
#   'total_amount': 78.99,
#   'inputs': [{'address': '1D93VKrgSynXT4NZ79mNEwFCS7N9YErZ7F',
#     'amount': Decimal('78.99000000'),
#     'time': 1299335271}],
#   'outputs': [{'address': '13CRiz2HMGh63VW2fafQWpXzVWVFaAQtCX',
#     'amount': Decimal('78.93000000'),
#     'time': 1299335271},
#    {'address': '18VdxoUJprHZADyLtcfTUYSy6udihi1jTZ',
#     'amount': Decimal('0.05000000'),
#     'time': 1299335271}]},
#  {'transaction_id': '7e7f650597133fbad37480b10c78df0baf6cdc798210781aa4d10c0b2588189b',
#   'total_amount': 78.93,
#   'inputs': [{'address': '13CRiz2HMGh63VW2fafQWpXzVWVFaAQtCX',
#     'amount': Decimal('78.93000000'),
#     'time': 1299336076}],
#   'outputs': [{'address': '1PAfQ8mdtKLVCtMUoWy6HL8SnHNPwCTrTx',
#     'amount': Decimal('78.87000000'),
#     'time': 1299336076},
#    {'address': '1NECBsKiSfM1niZ1a86i8DPohn6QbXF4Dw',
#     'amount': Decimal('0.05000000'),
#     'time': 1299336076}]},
#  {'transaction_id': '187c8ea2a25bd41a914670ac95744fb1deff197604965767cd530d2d7ef1e0b2',
#   'total_amount': 78.87,
#   'inputs': [{'address': '1PAfQ8mdtKLVCtMUoWy6HL8SnHNPwCTrTx',
#     'amount': Decimal('78.87000000'),
#     'time': 1299336076}],
#   'outputs': [{'address': '15i2STMkzXDhXJ4bk3DDoUkF28yJEG5Gy5',
#     'amount': Decimal('78.81000000'),
#     'time': 1299336076},
#    {'address': '1KbZnQBViz1XhFHeqPjpVZFFx7MsNTWkib',
#     'amount': Decimal('0.05000000'),
#     'time': 1299336076}]},
#  {'transaction_id': '5a9c483a87e78cad3b7a7cd72e26a92bbcb492eada38dd6b18a9439b131b0bf9',
#   'total_amount': 78.81,
#   'inputs': [{'address': '15i2STMkzXDhXJ4bk3DDoUkF28yJEG5Gy5',
#     'amount': Decimal('78.81000000'),
#     'time': 1299336076}],
#   'outputs': [{'address': '1BrZUaGMXzZBoWGbaQgBJrzJwK6j9wi1qH',
#     'amount': Decimal('0.05000000'),
#     'time': 1299336076},
#    {'address': '153Y9w6uqLUCz69exu5srjDdZLrZwgT6Xq',
#     'amount': Decimal('78.75000000'),
#     'time': 1299336076}]},
#  {'transaction_id': '8cf3b52c8d7bb28a20625f50c05e9eb88618eac8f157bde53064666d1e8a2093',
#   'total_amount': 78.75,
#   'inputs': [{'address': '153Y9w6uqLUCz69exu5srjDdZLrZwgT6Xq',
#     'amount': Decimal('78.75000000'),
#     'time': 1299336076}],
#   'outputs': [{'address': '18jnrHCRrfSf5tVwPJnu93DuPr7fsk5HZS',
#     'amount': Decimal('0.05000000'),
#     'time': 1299336076},
#    {'address': '1LujsXt6XFr75kpQYLgVnpTp2hy8Amuv4C',
#     'amount': Decimal('78.69000000'),
#     'time': 1299336076}]},
#  {'transaction_id': '9843dd49d89997cf781398c8dc0268f0532eee43465bc9cf1d8e1f5b5fa6821c',
#   'total_amount': 78.69,
#   'inputs': [{'address': '1LujsXt6XFr75kpQYLgVnpTp2hy8Amuv4C',
#     'amount': Decimal('78.69000000'),
#     'time': 1299336076}],
#   'outputs': [{'address': '1H4751Ywww61Wt3sdUsjsj6td4GovkVqko',
#     'amount': Decimal('0.05000000'),
#     'time': 1299336076},
#    {'address': '1tw5SGd2m2NJxpznVxyJvudMVAaSf1oxJ',
#     'amount': Decimal('78.63000000'),
#     'time': 1299336076}]},
#  {'transaction_id': '7e5d72333310d14efbeaf0c2124f00bf7859d2250342cac66d674cfd07792d9d',
#   'total_amount': 78.63,
#   'inputs': [{'address': '1tw5SGd2m2NJxpznVxyJvudMVAaSf1oxJ',
#     'amount': Decimal('78.63000000'),
#     'time': 1299336076}],
#   'outputs': [{'address': '1Li5wEZq9fYkwZGxA2EK87h7xmWHF3Zb4K',
#     'amount': Decimal('78.57000000'),
#     'time': 1299336076},
#    {'address': '1rx1R3dapXkd7TM7MFspdGQqtcs68ERJy',
#     'amount': Decimal('0.05000000'),
#     'time': 1299336076}]},
#  {'transaction_id': 'f08ce139f57aa1e0be8a4eed1c92ae7afe1ff769b38b87659ebb4e0ae7acaed3',
#   'total_amount': 78.57,
#   'inputs': [{'address': '1Li5wEZq9fYkwZGxA2EK87h7xmWHF3Zb4K',
#     'amount': Decimal('78.57000000'),
#     'time': 1299336076}],
#   'outputs': [{'address': '13XDjM6E5gGhBcwDzjknA62mFKNhY7nL7S',
#     'amount': Decimal('78.51000000'),
#     'time': 1299336076},
#    {'address': '1K6btWu93cLqqqTS2HTzUrHvkR8qD5Ecax',
#     'amount': Decimal('0.05000000'),
#     'time': 1299336076}]},
#  {'transaction_id': 'e89d866ccca46574d888e0443162a268a6061245f57d9be2bfeb5e46a76cd225',
#   'total_amount': 349.0,
#   'inputs': [{'address': '14PqrYgdYcea1nkTFqr3Teh4M3Bvd1uTvT',
#     'amount': Decimal('349.00000000'),
#     'time': 1299336857}],
#   'outputs': [{'address': '1Aojs7dxHTPjLWmFYPCZzS6BeCD8J7d6pu',
#     'amount': Decimal('100.00000000'),
#     'time': 1299336857},
#    {'address': '14C3uWZwMEqgFv5VMTeVUojrhKJ8Ke8fxD',
#     'amount': Decimal('249.00000000'),
#     'time': 1299336857}]},
#  {'transaction_id': '94e2c46af207e63a0d3e606251605c6bff79ed43ed4ff1d9faa0f2895b83d983',
#   'total_amount': 1.05,
#   'inputs': [{'address': '1K2CzucBKfYZThJDh7QSyBTHz3LhKqP2RR',
#     'amount': Decimal('1.05000000'),
#     'time': 1299336857}],
#   'outputs': [{'address': '13QHBShH2F3yi22yA6JFjG8vU2kLBfTqru',
#     'amount': Decimal('0.75000000'),
#     'time': 1299336857},
#    {'address': '15qwmFseu1r4K4ZByWiN5JB2xSLXXCMPfr',
#     'amount': Decimal('0.30000000'),
#     'time': 1299336857}]},
#  {'transaction_id': '5cfe86bfcd0844743eaed2bd1856b517891f6a3df7ea7f72978a1bcae6d664b1',
#   'total_amount': 49.6,
#   'inputs': [{'address': '1FDhBJec4GX8qesr9tcGFBugThvAKvwRNZ',
#     'amount': Decimal('49.60000000'),
#     'time': 1299336857}],
#   'outputs': [{'address': '1Mbab6GPgAo3zspD4VC5EPUH6A1BR1CWKx',
#     'amount': Decimal('49.08000000'),
#     'time': 1299336857},
#    {'address': '1M2tcL5kJvU4AznwGpSJqC9LNvNCSHbMDP',
#     'amount': Decimal('0.52000000'),
#     'time': 1299336857}]},
#  {'transaction_id': '939615ccc53a782ed78eb73b9cc0a01ecd56a2f45957ea7682d5f7a614e96986',
#   'total_amount': 9.9,
#   'inputs': [{'address': '1CgJw4rhy1cZrW3QxusDzhfigLKRjHWb5k',
#     'amount': Decimal('9.90000000'),
#     'time': 1299336857}],
#   'outputs': [{'address': '1AGAQEw8XwzzCFYVnYQF3uFhqYYVuhCP18',
#     'amount': Decimal('9.86000000'),
#     'time': 1299336857},
#    {'address': '1NbLPvDEvpcbKXKoAukwMaoXKJeDgRpbyy',
#     'amount': Decimal('0.04000000'),
#     'time': 1299336857}]},
#  {'transaction_id': '7e64b7cb4e58b975b071195f4ffdfaf8593f70da51f05cb56b7b2502ad76578d',
#   'total_amount': 14.10000002,
#   'inputs': [{'address': '19hxWjYCufwPFquKW1xANp3QLyqDYLAUc4',
#     'amount': Decimal('14.10000002'),
#     'time': 1299336857}],
#   'outputs': [{'address': '1429nCWeABn6A9k8Jyb11mgDZgHG7oejb5',
#     'amount': Decimal('13.98000002'),
#     'time': 1299336857},
#    {'address': '1CtNGMTrzraQuQhvcR33haTw2Erg2tWF5M',
#     'amount': Decimal('0.12000000'),
#     'time': 1299336857}]},
#  {'transaction_id': 'c8327e475f1c90126116d5081c66c1efbbbc44db3ecef8615984a623e7addcac',
#   'total_amount': 78.51,
#   'inputs': [{'address': '13XDjM6E5gGhBcwDzjknA62mFKNhY7nL7S',
#     'amount': Decimal('78.51000000'),
#     'time': 1299336857}],
#   'outputs': [{'address': '1HDr5C3H2Qgh69Bdds4ZhiLaJxRFAwr8Vv',
#     'amount': Decimal('0.05000000'),
#     'time': 1299336857},
#    {'address': '1JXrF6FomDF8MuDxhZmSv8s3SA8SfMGbkN',
#     'amount': Decimal('78.45000000'),
#     'time': 1299336857}]},
#  {'transaction_id': '377f7eb064f4fb15c4e22b8c9e783ceb82be493184455b6b692c734f7503b5bf',
#   'total_amount': 78.45,
#   'inputs': [{'address': '1JXrF6FomDF8MuDxhZmSv8s3SA8SfMGbkN',
#     'amount': Decimal('78.45000000'),
#     'time': 1299336857}],
#   'outputs': [{'address': '19TEkJpyNbET25tBQBCsgsEUM171XToYw7',
#     'amount': Decimal('0.05000000'),
#     'time': 1299336857},
#    {'address': '18mQRFqrHewHHbkdYGBYnmZ6njtjByVuG5',
#     'amount': Decimal('78.39000000'),
#     'time': 1299336857}]},
#  {'transaction_id': 'd30566b83056e35d26c6e50ef070e3b847a5aad45f4db17ede3ca484f3fc9b3c',
#   'total_amount': 78.39,
#   'inputs': [{'address': '18mQRFqrHewHHbkdYGBYnmZ6njtjByVuG5',
#     'amount': Decimal('78.39000000'),
#     'time': 1299336857}],
#   'outputs': [{'address': '1HQbFep3KRW3hbfFB2ipWuFQEaGGJL8aK8',
#     'amount': Decimal('0.05000000'),
#     'time': 1299336857},
#    {'address': '12ZJ6HN2fKGttuWDTHVgmYmJomX4zLZH2r',
#     'amount': Decimal('78.33000000'),
#     'time': 1299336857}]},
#  {'transaction_id': '98ebb28e95a531822975818222e24040da21bec37bc733acdd18a0e50094f562',
#   'total_amount': 78.33,
#   'inputs': [{'address': '12ZJ6HN2fKGttuWDTHVgmYmJomX4zLZH2r',
#     'amount': Decimal('78.33000000'),
#     'time': 1299336857}],
#   'outputs': [{'address': '1B7PxW3JGKBiWkniTt353JdfWntESAdji8',
#     'amount': Decimal('78.27000000'),
#     'time': 1299336857},
#    {'address': '1JihRm3THhJdsfutSX25gS34EwpxoEiCAm',
#     'amount': Decimal('0.05000000'),
#     'time': 1299336857}]},
#  {'transaction_id': 'ade95e3f2f6154a20ed9fde5ca06b8e09dfd0a85ffb07082b57f159a41294942',
#   'total_amount': 78.27,
#   'inputs': [{'address': '1B7PxW3JGKBiWkniTt353JdfWntESAdji8',
#     'amount': Decimal('78.27000000'),
#     'time': 1299336857}],
#   'outputs': [{'address': '1CeKdzbS8xJVVGYDqzt7tjy5pddsxmYpdE',
#     'amount': Decimal('0.05000000'),
#     'time': 1299336857},
#    {'address': '1MqkPaDcg3uXtGw3A2d29yj4z1wDiXsTiH',
#     'amount': Decimal('78.21000000'),
#     'time': 1299336857}]},
#  {'transaction_id': 'bf23b950718041a2c118ef6958d34d8ec20ca72149239ea86e7fe2cdf6a67537',
#   'total_amount': 1.52,
#   'inputs': [{'address': '1ALanCy1NcbF2muRgLXUwSmig83k6FQSKW',
#     'amount': Decimal('1.52000000'),
#     'time': 1299337092}],
#   'outputs': [{'address': '1NrK8BEBHzs1fibMyoHDV9urLckzaLMQDB',
#     'amount': Decimal('1.00000000'),
#     'time': 1299337092},
#    {'address': '1JvN3AY6vLTFMSFL945dh3QwJxa3deMvgT',
#     'amount': Decimal('0.52000000'),
#     'time': 1299337092}]},
#  {'transaction_id': '4015b10b0576f94b65db5e04784675e3902b3b6d322b9441d4874bcd6835690d',
#   'total_amount': 9.049999999999999,
#   'inputs': [{'address': '1P9Bvaun4dCzc3s2axcqaXqazJTpVbDCyM',
#     'amount': Decimal('7.85000000'),
#     'time': 1299337092},
#    {'address': '1Afb6nDoDcd3oUJ2XzHAVEwk8jzKeseBqZ',
#     'amount': Decimal('1.20000000'),
#     'time': 1299337092}],
#   'outputs': [{'address': '19fg5975zPC7NPz5TscRjrDFeyiZjvNUeV',
#     'amount': Decimal('1.05000000'),
#     'time': 1299337092},
#    {'address': '1718abKP1QxNyMmsSoZh7iz1HK8DRTJSKu',
#     'amount': Decimal('8.00000000'),
#     'time': 1299337092}]},
#  {'transaction_id': '4a0e4afde25dfadab7527d7d20777f8506ef791a934f95a31216dd6987c00b4b',
#   'total_amount': 0.05,
#   'inputs': [{'address': '1AFip23zn1YeUcD4aaXEZbqTUwP6XZquFk',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337092}],
#   'outputs': [{'address': '13DLjn3iCAZsfUZiCtHZMdFpBjTzfB7K87',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337092}]},
#  {'transaction_id': 'd2a71d5b2943be2927c18568201fa85bc8b07dfed0a73366531cc87c412012e3',
#   'total_amount': 0.05,
#   'inputs': [{'address': '151fDoRu63w5eABAeo8zBYrxYVTSLhGif1',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337092}],
#   'outputs': [{'address': '15VjRaDX9zpbA8LVnbrCAFzrVzN7ixHNsC',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337092}]},
#  {'transaction_id': 'b7f3bfc008b6347a335f5b6a51a0b7fd40807d7d7d5eb09ecf4a4e1641fb7915',
#   'total_amount': 0.11,
#   'inputs': [{'address': '15bMRFFhyQj7xgBuuuYBAoVe9HHKpVmykv',
#     'amount': Decimal('0.11000000'),
#     'time': 1299337092}],
#   'outputs': [{'address': '1DXwnqjHhya1t9zNrAcYvUEvu7DWiAMRrV',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337092},
#    {'address': '1AyEymToeVM6kn28C91FWVvZov3iqdCPaH',
#     'amount': Decimal('0.06000000'),
#     'time': 1299337092}]},
#  {'transaction_id': '53567a3d66566b7e6975775127b311ee5c7c72fdfa74d5b41e45d13e4c215fc4',
#   'total_amount': 0.05,
#   'inputs': [{'address': '16rhS5r5mhV37hQG8SKmh8hcA9E8UczDxD',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337092}],
#   'outputs': [{'address': '1LawPtUTTiZuiDy9NcvQG9p8qCkqHnfAsH',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337092}]},
#  {'transaction_id': 'c99ea05c9581d37048549847a6e22acaf93a4abbf3fc3a8ba2e029da0c8ca47c',
#   'total_amount': 0.05,
#   'inputs': [{'address': '19KqV3m2kAdZaYzun2LF7JaV1Z5WhiUdHx',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337092}],
#   'outputs': [{'address': '1NbLPvDEvpcbKXKoAukwMaoXKJeDgRpbyy',
#     'amount': Decimal('0.04000000'),
#     'time': 1299337092},
#    {'address': '1GCWVYCkBmP7pPeTUt1xzPzWY5HPwZ595R',
#     'amount': Decimal('0.01000000'),
#     'time': 1299337092}]},
#  {'transaction_id': 'e11dd7f6490c5e19bcf98e65788a6293052f8e937ba03c87bc446c70b2716a9b',
#   'total_amount': 0.2,
#   'inputs': [{'address': '1F5yzsUWAq83o69Ur7obV5qTXy5MqvUALe',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337092},
#    {'address': '18CwG39rHcgeVQ4T8JXzXVMTBvy8x8RwSh',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337092},
#    {'address': '1LZj6QufSsuYEtKSQKJxPPTCZs8FjHcv8R',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337092},
#    {'address': '14N5hnF4XYiYiYe8S43DSsg7hASidd3PUT',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337092}],
#   'outputs': [{'address': '1KYSZEzUFzBUFWt37waNBmLqUebXSq2ddG',
#     'amount': Decimal('0.20000000'),
#     'time': 1299337092}]},
#  {'transaction_id': '257f1c4b94eb9de8b390652844f4a432b49beb8545d7b61b6a608491b8fd43ad',
#   'total_amount': 1.01,
#   'inputs': [{'address': '1L9pHdwazp5T94LB2oP4G1TxFtRbGdiT4m',
#     'amount': Decimal('1.01000000'),
#     'time': 1299337274}],
#   'outputs': [{'address': '1GbDZHYS53qWoudPDxnC8rDmTRq9e3gJmF',
#     'amount': Decimal('0.99000000'),
#     'time': 1299337274},
#    {'address': '17bjEq8pJYFmYEuC7E2t5UJyfSzqy3tzS2',
#     'amount': Decimal('0.02000000'),
#     'time': 1299337274}]},
#  {'transaction_id': '4a05e96043134cbcadf437e1491af38c00365be23794276dc089d9e1deb371ca',
#   'total_amount': 5.0,
#   'inputs': [{'address': '154BxkTXosa6AbaJMKMC5fFMFucTHSzvJn',
#     'amount': Decimal('5.00000000'),
#     'time': 1299337274}],
#   'outputs': [{'address': '18yLuyuWF7Re655vR2bwYkryoUNoFzab3y',
#     'amount': Decimal('5.00000000'),
#     'time': 1299337274}]},
#  {'transaction_id': '591df91842e5e81d99127a35141dab420eb9a63362359b41d486757a28a2682d',
#   'total_amount': 0.22,
#   'inputs': [{'address': '18YuGYo6s5WaBMrFW6gAxaXZ4wGVMQh3kv',
#     'amount': Decimal('0.22000000'),
#     'time': 1299337274}],
#   'outputs': [{'address': '1FYNqRPBeSsY66jxvM78eAMC3brUseNuAY',
#     'amount': Decimal('0.14000000'),
#     'time': 1299337274},
#    {'address': '1K4xTmk1JsXheLSsFvcGrR26vFgjXKRmtv',
#     'amount': Decimal('0.08000000'),
#     'time': 1299337274}]},
#  {'transaction_id': '2ecc717f6a0a2440696b0c2f91229d81c67d379d68ab4bbb51e76dff8fbf7999',
#   'total_amount': 78.21,
#   'inputs': [{'address': '1MqkPaDcg3uXtGw3A2d29yj4z1wDiXsTiH',
#     'amount': Decimal('78.21000000'),
#     'time': 1299337631}],
#   'outputs': [{'address': '1APu86PZVFyQoJ5M8QY2s6cJ1tGV51d7W2',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337631},
#    {'address': '15QrtT1jeQ2DGLeM1AwEKxtxTgNzyUCbAt',
#     'amount': Decimal('78.15000000'),
#     'time': 1299337631}]},
#  {'transaction_id': '16fa23d7f5a8da3db18c70e4a697233c3569011ff4d63ff99039c0797071e4b0',
#   'total_amount': 0.05,
#   'inputs': [{'address': '14hLg4DuwufyANtqsP1FRbjecxg7yTBM6M',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337631}],
#   'outputs': [{'address': '18HozwTEfrs5en5Rx4RVJbxS4uotNxZLUo',
#     'amount': Decimal('0.05000000'),
#     'time': 1299337631}]},
#  {'transaction_id': '151d6c5b77ba163fefb2a4d3ccd7f6ac8eac9c813136d121960a1649db62a681',
#   'total_amount': 2.0,
#   'inputs': [{'address': '1CB1zgokA6mPDCvJG6iU541kjXAW8LRyKt',
#     'amount': Decimal('2.00000000'),
#     'time': 1299337909}],
#   'outputs': [{'address': '19kLyWDCpaEMXo6dbx2YRN3N7Zwp8M7PxB',
#     'amount': Decimal('1.00000000'),
#     'time': 1299337909},
#    {'address': '13MGAPHHRvbheTeS6eyi64ghuKHeV3unvB',
#     'amount': Decimal('1.00000000'),
#     'time': 1299337909}]},
#  {'transaction_id': 'ae8c6e007c8f5436bd204551a5f3faac0098b686928ddab601cb2a12c1e2447c',
#   'total_amount': 0.14,
#   'inputs': [{'address': '1FYNqRPBeSsY66jxvM78eAMC3brUseNuAY',
#     'amount': Decimal('0.14000000'),
#     'time': 1299337909}],
#   'outputs': [{'address': '1K4xTmk1JsXheLSsFvcGrR26vFgjXKRmtv',
#     'amount': Decimal('0.08000000'),
#     'time': 1299337909},
#    {'address': '19EUNj2r8Hg5BDmkZLGwC5jvhKAMCU6aA4',
#     'amount': Decimal('0.06000000'),
#     'time': 1299337909}]},
#  {'transaction_id': 'dcf6595431ba87d95bd9ab33e47343a92ab6722fb6dda17a7f02477ecd41a4a6',
#   'total_amount': 1.36,
#   'inputs': [{'address': '1gYykhVk32RdLhYfe5S1W3e5JJLtxpaBK',
#     'amount': Decimal('1.36000000'),
#     'time': 1299338838}],
#   'outputs': [{'address': '15oe6gqT93a6kdFbikzxEkfHLf1nKxMAF8',
#     'amount': Decimal('1.36000000'),
#     'time': 1299338838}]},
#  {'transaction_id': '7f618103e4365d8fced62c36e95d3cd6b6385bb983d1d6c0adbe8f06a932d043',
#   'total_amount': 78.15,
#   'inputs': [{'address': '15QrtT1jeQ2DGLeM1AwEKxtxTgNzyUCbAt',
#     'amount': Decimal('78.15000000'),
#     'time': 1299338838}],
#   'outputs': [{'address': '1DUL81u5K3c8JC858ochKJ6QijHLR3pCTX',
#     'amount': Decimal('78.09000000'),
#     'time': 1299338838},
#    {'address': '15jhSqx67uym2SPdfmRFwujnHNwtvq4w4i',
#     'amount': Decimal('0.05000000'),
#     'time': 1299338838}]},
#  {'transaction_id': 'b12aada0731c2b224ff01c58263fd233c62db5ed5f4e80d0d975bd77cfcca750',
#   'total_amount': 0.07,
#   'inputs': [{'address': '13qwwVn5ijFLjCUMgGedK5mWta7hsDsD8F',
#     'amount': Decimal('0.02000000'),
#     'time': 1299338838},
#    {'address': '15VjRaDX9zpbA8LVnbrCAFzrVzN7ixHNsC',
#     'amount': Decimal('0.05000000'),
#     'time': 1299338838}],
#   'outputs': [{'address': '1J7svSNfAgpRYijLm23eSbwbMx8RVJqkVH',
#     'amount': Decimal('0.01000000'),
#     'time': 1299338838},
#    {'address': '1ERjCuihV41v5RUrcwdsmm9igCrrtFXLyv',
#     'amount': Decimal('0.05000000'),
#     'time': 1299338838}]},
#  {'transaction_id': 'a5cf3d8efc3a5264d2d57d546bab0bd96172f2e19eff4edd20be38b8c48c869f',
#   'total_amount': 78.09,
#   'inputs': [{'address': '1DUL81u5K3c8JC858ochKJ6QijHLR3pCTX',
#     'amount': Decimal('78.09000000'),
#     'time': 1299338838}],
#   'outputs': [{'address': '16nWvuXUpuExbVVVbpj9WaUh17wNwdXX67',
#     'amount': Decimal('78.03000000'),
#     'time': 1299338838},
#    {'address': '1BrnyLoWW8PKBfBCJXve1qYXZ8pHmFsdau',
#     'amount': Decimal('0.05000000'),
#     'time': 1299338838}]},
#  {'transaction_id': 'd16e6314e77c86b13e61a0e52a10967402df997342c990ca532adf050d2a7980',
#   'total_amount': 78.03,
#   'inputs': [{'address': '16nWvuXUpuExbVVVbpj9WaUh17wNwdXX67',
#     'amount': Decimal('78.03000000'),
#     'time': 1299338838}],
#   'outputs': [{'address': '1DcYcT59vChGDx9NPQDyLyanMvzGSJNLad',
#     'amount': Decimal('77.97000000'),
#     'time': 1299338838},
#    {'address': '1VtkBBiegHH2NDUkcbyNXE5bkkaHHbjnz',
#     'amount': Decimal('0.05000000'),
#     'time': 1299338838}]},
#  {'transaction_id': '88d2692d79553ded54d3061831d0a3ad58aec1c21e5a5302126686526f4fb019',
#   'total_amount': 77.97,
#   'inputs': [{'address': '1DcYcT59vChGDx9NPQDyLyanMvzGSJNLad',
#     'amount': Decimal('77.97000000'),
#     'time': 1299338838}],
#   'outputs': [{'address': '1JGi11DyyBuHMhWsudQeumqezysuvbjzJV',
#     'amount': Decimal('0.05000000'),
#     'time': 1299338838},
#    {'address': '1LemxCohjpjHfm69n1x3kpLpjhyionfWn4',
#     'amount': Decimal('77.91000000'),
#     'time': 1299338838}]},
#  {'transaction_id': '128b29efe9fe795495abfd74721d80d933287f079dff0015f0ab0eaf89f5adc5',
#   'total_amount': 77.91,
#   'inputs': [{'address': '1LemxCohjpjHfm69n1x3kpLpjhyionfWn4',
#     'amount': Decimal('77.91000000'),
#     'time': 1299338838}],
#   'outputs': [{'address': '1JtbrGGuX9M6rjgaroKRrTLzvkuJi5dgYX',
#     'amount': Decimal('0.05000000'),
#     'time': 1299338838},
#    {'address': '1MBqvqb5GfHV7LuCQFHua75bKEdNA5jHK9',
#     'amount': Decimal('77.85000000'),
#     'time': 1299338838}]},
#  {'transaction_id': '088b2dd2e9d1b66dd0e5605a800d5105ee5d3509532c800812c51017b36c5a7b',
#   'total_amount': 77.85,
#   'inputs': [{'address': '1MBqvqb5GfHV7LuCQFHua75bKEdNA5jHK9',
#     'amount': Decimal('77.85000000'),
#     'time': 1299338838}],
#   'outputs': [{'address': '1K8mmd8bpEx2AkbbeGTSQj6z4uc9JTBHAH',
#     'amount': Decimal('77.79000000'),
#     'time': 1299338838},
#    {'address': '1Ch8TUSJ2Pej6L2rNV8TrYzb66QokjtgYj',
#     'amount': Decimal('0.05000000'),
#     'time': 1299338838}]},
#  {'transaction_id': 'e1f95b1653f21f613f01f5c95fa3d8403a315cc17f4eb027d3b41d6c51960d23',
#   'total_amount': 77.79,
#   'inputs': [{'address': '1K8mmd8bpEx2AkbbeGTSQj6z4uc9JTBHAH',
#     'amount': Decimal('77.79000000'),
#     'time': 1299338838}],
#   'outputs': [{'address': '1KatiRWimJw78Bt9zP35RjFMCNq1eVF76s',
#     'amount': Decimal('77.73000000'),
#     'time': 1299338838},
#    {'address': '12V1yLTh1bEeu2MtEiNqDWDGrtUnHUW9M8',
#     'amount': Decimal('0.05000000'),
#     'time': 1299338838}]},
#  {'transaction_id': 'd77c98a65b4924a2b056d6773deb018723877e815afa6ac62b590acbb82aa383',
#   'total_amount': 70.0,
#   'inputs': [{'address': '1AZ9LEGc54U1bgzv5MEKq7vSod2X8NJtJK',
#     'amount': Decimal('70.00000000'),
#     'time': 1299339448}],
#   'outputs': [{'address': '1GoobfJ7SLL4YzBvwdX3RSkwFNsYNxgenT',
#     'amount': Decimal('30.00000000'),
#     'time': 1299339448},
#    {'address': '1FxzNgSPVzvbvz3sb28Dhp9jCJztpdW7sv',
#     'amount': Decimal('40.00000000'),
#     'time': 1299339448}]},
#  {'transaction_id': 'ec76985453b6c3b131ca889463bdfcad2c4290e2f7127809ee668d9362748be6',
#   'total_amount': 49.08,
#   'inputs': [{'address': '1Mbab6GPgAo3zspD4VC5EPUH6A1BR1CWKx',
#     'amount': Decimal('49.08000000'),
#     'time': 1299339448}],
#   'outputs': [{'address': '1JCeuFdx4ToQoPp6CAxSUW6ytQPpV7jkLc',
#     'amount': Decimal('49.07000000'),
#     'time': 1299339448},
#    {'address': '14LMtkx7t2qHr4F4b6hCz4rMA5xZe2EbxG',
#     'amount': Decimal('0.01000000'),
#     'time': 1299339448}]},
#  {'transaction_id': 'd6e87770468b9c4833df926482e40b5eac64ba97288e7f359a3531f3d5a7615f',
#   'total_amount': 77.73,
#   'inputs': [{'address': '1KatiRWimJw78Bt9zP35RjFMCNq1eVF76s',
#     'amount': Decimal('77.73000000'),
#     'time': 1299339448}],
#   'outputs': [{'address': '1L6BfpZ2ZQ5cDkokuo8UM6MsX4Ci7zhNFV',
#     'amount': Decimal('77.67000000'),
#     'time': 1299339448},
#    {'address': '1CTwUKRm9Yck6596nCHygMAKELEBbndG6f',
#     'amount': Decimal('0.05000000'),
#     'time': 1299339448}]},
#  {'transaction_id': '80371066cc7f199bd032d99129ab73eb19f7e5b3c218faf2b0c4bd6581048c3b',
#   'total_amount': 13.98000002,
#   'inputs': [{'address': '1429nCWeABn6A9k8Jyb11mgDZgHG7oejb5',
#     'amount': Decimal('13.98000002'),
#     'time': 1299339448}],
#   'outputs': [{'address': '17bumTdaAnmHuafresoDFJnVa9sjsxyc5V',
#     'amount': Decimal('13.78000002'),
#     'time': 1299339448},
#    {'address': '12LQbqJc3TZWFgPHWyVf4UcZwxB6tFB38m',
#     'amount': Decimal('0.20000000'),
#     'time': 1299339448}]},
#  {'transaction_id': 'ce18f8a6ebf0a42a5cf6b8ce525ec5179b1998604d71058bd0d55cdca62575cc',
#   'total_amount': 7.0,
#   'inputs': [{'address': '13kWJNUoTgSX6EJvnnf6FzdizBxNmmsVVP',
#     'amount': Decimal('1.00000000'),
#     'time': 1299339448},
#    {'address': '13kWJNUoTgSX6EJvnnf6FzdizBxNmmsVVP',
#     'amount': Decimal('0.05000000'),
#     'time': 1299339448},
#    {'address': '1FunMatPo1mn9cLVNbxfNqU5ty1XfgEmDC',
#     'amount': Decimal('0.01000000'),
#     'time': 1299339448},
#    {'address': '13mbARjSCv4Sm3xdiMB2DJScq6wSvCKerJ',
#     'amount': Decimal('0.04000000'),
#     'time': 1299339448},
#    {'address': '13kWJNUoTgSX6EJvnnf6FzdizBxNmmsVVP',
#     'amount': Decimal('5.55000000'),
#     'time': 1299339448},
#    {'address': '1Cj868LYtjv7CK5pLoanM5mxVT5NGNHY3C',
#     'amount': Decimal('0.35000000'),
#     'time': 1299339448}],
#   'outputs': [{'address': '1DwvJdyx9eKprtVAamFCMF7tCegF6NGnCu',
#     'amount': Decimal('7.00000000'),
#     'time': 1299339448}]},
#  {'transaction_id': 'df6b4b178c02deff9bf163779c31c2f5f269d18e611c5ac699878c69d5a60122',
#   'total_amount': 0.05,
#   'inputs': [{'address': '1Q1Shyqa76xXiioroGWzsSMZ8mh12kHwkn',
#     'amount': Decimal('0.05000000'),
#     'time': 1299339448}],
#   'outputs': [{'address': '1D2KfsxBbnRmrmXY8v6aMKKqUSq7GcmHmi',
#     'amount': Decimal('0.04000000'),
#     'time': 1299339448}]},
#  {'transaction_id': 'a3800ad4b4ac1f1ea3ab67de162f21d782d3b6e9ed97de5bf5af4ffe1c60f0bb',
#   'total_amount': 0.05,
#   'inputs': [{'address': '1VtkBBiegHH2NDUkcbyNXE5bkkaHHbjnz',
#     'amount': Decimal('0.05000000'),
#     'time': 1299339448}],
#   'outputs': [{'address': '14ExronPRN44urf4jqPMyoAN46T75MKGgP',
#     'amount': Decimal('0.05000000'),
#     'time': 1299339448}]},
#  {'transaction_id': 'a1e1a0e55139ab633949386b59d98b8280a0ec125332f54813f521a769c7b812',
#   'total_amount': 77.67,
#   'inputs': [{'address': '1L6BfpZ2ZQ5cDkokuo8UM6MsX4Ci7zhNFV',
#     'amount': Decimal('77.67000000'),
#     'time': 1299339448}],
#   'outputs': [{'address': '1GMW5e8MGYpB2eG1MXyKVjY5pp6dhKvnKr',
#     'amount': Decimal('77.61000000'),
#     'time': 1299339448},
#    {'address': '19pSowRrL7hL9fya2sDqYdsB3FxbjcwX3X',
#     'amount': Decimal('0.05000000'),
#     'time': 1299339448}]},
#  {'transaction_id': 'f043c44b4a50ff639abe9fc5ae8106c162ef71215abe6daf2d0a3ea2e51aa9e5',
#   'total_amount': 77.61,
#   'inputs': [{'address': '1GMW5e8MGYpB2eG1MXyKVjY5pp6dhKvnKr',
#     'amount': Decimal('77.61000000'),
#     'time': 1299339448}],
#   'outputs': [{'address': '1EuAUGNXtCsec9i65CFgCaJJfHE9iCBffC',
#     'amount': Decimal('0.05000000'),
#     'time': 1299339448},
#    {'address': '1FSKBaNyRmwEHhAtQyGJW3r6XygiduGnQx',
#     'amount': Decimal('77.55000000'),
#     'time': 1299339448}]},
#  {'transaction_id': '7212625d49b3c2af270e277a6e5bf507ec956a82efe4578163fd94ac04fbbc2f',
#   'total_amount': 77.55,
#   'inputs': [{'address': '1FSKBaNyRmwEHhAtQyGJW3r6XygiduGnQx',
#     'amount': Decimal('77.55000000'),
#     'time': 1299339448}],
#   'outputs': [{'address': '1PUBccyCdFiKU2dArpP9MAYdH4vAd11Zbe',
#     'amount': Decimal('0.05000000'),
#     'time': 1299339448},
#    {'address': '1AKG4LaY4TB5fd2XDovdCnCJ6phEgCKXtk',
#     'amount': Decimal('77.49000000'),
#     'time': 1299339448}]},
#  {'transaction_id': '548b32cd3da10d9472b78ef2bc2d24090c825898c73d82a640ab7c060c14a420',
#   'total_amount': 77.49,
#   'inputs': [{'address': '1AKG4LaY4TB5fd2XDovdCnCJ6phEgCKXtk',
#     'amount': Decimal('77.49000000'),
#     'time': 1299339915}],
#   'outputs': [{'address': '1BEDV7azCJJ87Fuqyp8eGEzQjfHv8pLsBa',
#     'amount': Decimal('77.43000000'),
#     'time': 1299339915},
#    {'address': '1D88dMcBxoyJ6hyGtqArM79ioT8nC9oSaq',
#     'amount': Decimal('0.05000000'),
#     'time': 1299339915}]},
#  {'transaction_id': 'a58fe7bbde9a80257729f26c7c194fedcfb481511f4e946ec3b5f08e04e118d3',
#   'total_amount': 77.43,
#   'inputs': [{'address': '1BEDV7azCJJ87Fuqyp8eGEzQjfHv8pLsBa',
#     'amount': Decimal('77.43000000'),
#     'time': 1299339915}],
#   'outputs': [{'address': '1HAaCrnwi9123fciAdPPrBKU44J7QFTarU',
#     'amount': Decimal('0.05000000'),
#     'time': 1299339915},
#    {'address': '17JmURTwBXCSPsBJBwoWSEy5eMwsaMofaM',
#     'amount': Decimal('77.37000000'),
#     'time': 1299339915}]},
#  {'transaction_id': '82a2071ca08ea71b872b467772a09122869818b0d80815abd6236369014f037e',
#   'total_amount': 77.37,
#   'inputs': [{'address': '17JmURTwBXCSPsBJBwoWSEy5eMwsaMofaM',
#     'amount': Decimal('77.37000000'),
#     'time': 1299339915}],
#   'outputs': [{'address': '1CYj9buhTxDjUV8FYFDamTZwVDrS9g4y6k',
#     'amount': Decimal('77.31000000'),
#     'time': 1299339915},
#    {'address': '1H4vmBtDNusGpxWXSbjQGrpqVpiEcgXWMS',
#     'amount': Decimal('0.05000000'),
#     'time': 1299339915}]},
#  {'transaction_id': '2894b419e0cf5692c9f8642406d3b7c035f8ad672488c11836d24f74643dffec',
#   'total_amount': 77.31,
#   'inputs': [{'address': '1CYj9buhTxDjUV8FYFDamTZwVDrS9g4y6k',
#     'amount': Decimal('77.31000000'),
#     'time': 1299339915}],
#   'outputs': [{'address': '1GispBYR4E9n1pEdjzKi8NJBwSmj4hd1r4',
#     'amount': Decimal('77.25000000'),
#     'time': 1299339915},
#    {'address': '185rhbKMyycv7tU3DJoaDGqS3ALhwDTf3w',
#     'amount': Decimal('0.05000000'),
#     'time': 1299339915}]},
#  {'transaction_id': '0acb56a439e75350c4e0781a63b307224a966115c4d22ca1206006adac1cf48b',
#   'total_amount': 0.5000000000000002,
#   'inputs': [{'address': '1FVEkJygYiG9zvdszmaoD73VYtrKQeTi9L',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1HckHcdZbYhALzLBHRZhMBf642yf3HFePm',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FVEkJygYiG9zvdszmaoD73VYtrKQeTi9L',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FVEkJygYiG9zvdszmaoD73VYtrKQeTi9L',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1N4McG3nrrjhBVSBoa8S5avgadx96ghRqE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1NivpaMavJLmjur5T96h1Eqwhu1D2pciSr',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1N4McG3nrrjhBVSBoa8S5avgadx96ghRqE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1N4McG3nrrjhBVSBoa8S5avgadx96ghRqE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1N4McG3nrrjhBVSBoa8S5avgadx96ghRqE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FVEkJygYiG9zvdszmaoD73VYtrKQeTi9L',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605}],
#   'outputs': [{'address': '1CstAgmnxNzn2NrQMc6BNtw5fLenRj6mwu',
#     'amount': Decimal('0.50000000'),
#     'time': 1299340605}]},
#  {'transaction_id': '34073ca74a205fb4dc25b5af30b8df1c19eea1b9f1b90b1051eacd1bf9e2848b',
#   'total_amount': 0.5000000000000002,
#   'inputs': [{'address': '1NivpaMavJLmjur5T96h1Eqwhu1D2pciSr',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1N4McG3nrrjhBVSBoa8S5avgadx96ghRqE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1NivpaMavJLmjur5T96h1Eqwhu1D2pciSr',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1NivpaMavJLmjur5T96h1Eqwhu1D2pciSr',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1N4McG3nrrjhBVSBoa8S5avgadx96ghRqE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FVEkJygYiG9zvdszmaoD73VYtrKQeTi9L',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1ByyMRgMTW4nARE4aqSi83KpB4kFrzyQDN',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1N4McG3nrrjhBVSBoa8S5avgadx96ghRqE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1N4McG3nrrjhBVSBoa8S5avgadx96ghRqE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1N4McG3nrrjhBVSBoa8S5avgadx96ghRqE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1N4McG3nrrjhBVSBoa8S5avgadx96ghRqE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1N4McG3nrrjhBVSBoa8S5avgadx96ghRqE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FVEkJygYiG9zvdszmaoD73VYtrKQeTi9L',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605}],
#   'outputs': [{'address': '1CstAgmnxNzn2NrQMc6BNtw5fLenRj6mwu',
#     'amount': Decimal('0.50000000'),
#     'time': 1299340605}]},
#  {'transaction_id': '3f450399a36fe7f4247cfabe88e0e8ac689fce4763fe8de7ff5c52fd2819b980',
#   'total_amount': 0.5000000000000002,
#   'inputs': [{'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1NivpaMavJLmjur5T96h1Eqwhu1D2pciSr',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1NivpaMavJLmjur5T96h1Eqwhu1D2pciSr',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1NivpaMavJLmjur5T96h1Eqwhu1D2pciSr',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1NivpaMavJLmjur5T96h1Eqwhu1D2pciSr',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FVEkJygYiG9zvdszmaoD73VYtrKQeTi9L',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1ByyMRgMTW4nARE4aqSi83KpB4kFrzyQDN',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FVEkJygYiG9zvdszmaoD73VYtrKQeTi9L',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1CowEEnDWpSxpBH5gfEfXoXN755hxGGKwL',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1N4McG3nrrjhBVSBoa8S5avgadx96ghRqE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FA6xjFVy4mNTMM8ALUu7NatA8KG7nBzgX',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605},
#    {'address': '1FVEkJygYiG9zvdszmaoD73VYtrKQeTi9L',
#     'amount': Decimal('0.01000000'),
#     'time': 1299340605}],
#   'outputs': [{'address': '1CstAgmnxNzn2NrQMc6BNtw5fLenRj6mwu',
#     'amount': Decimal('0.50000000'),
# ...
#     'amount': Decimal('2.57000000'),
#     'time': 1299380693},
#    {'address': '1AqYnR1pdbmmozD585EnupmCGN1kSVg2AN',
#     'amount': Decimal('26.21000000'),
#     'time': 1299380693}]},
#  {'transaction_id': '825b6703b9d002ec0f671c2341315cc630d8572d48f215bcaf226c2f72019a94',
#   'total_amount': 26.55,
#   'inputs': [{'address': '1CL39rPdNeTNcRNEKUNGd4xsHdCw4jygZ3',
#     'amount': Decimal('26.55000000'),
#     'time': 1299380693}],
#   'outputs': [{'address': '191gaa6CsCrpu6kPYxr7Zds72Nd773hCXt',
#     'amount': Decimal('5.07000000'),
#     'time': 1299380693},
#    {'address': '17hFyc2rGBWNJCjqXAXaTSU4gNYkoE73FH',
#     'amount': Decimal('21.48000000'),
#     'time': 1299380693}]},
#  {'transaction_id': 'b44a779cd9c661bf730babdf8982de0d9d9a7084ff4ea8f1ceb6561db672d3ef',
#   'total_amount': 50.02,
#   'inputs': [{'address': '12WFtKBsRLtV8p1NwRqe7YwYdi1rjwTZhA',
#     'amount': Decimal('50.02000000'),
#     'time': 1299380693}],
#   'outputs': [{'address': '12mcF29MTcJxpKhe4PiggpneTpFQqux1Ho',
#     'amount': Decimal('0.39000000'),
#     'time': 1299380693},
#    {'address': '1JvGmxfBo69DvmcVZyopP5ErEFaE226m7B',
#     'amount': Decimal('49.63000000'),
#     'time': 1299380693}]},
#  {'transaction_id': '251cf89e3fd6dffa3d4e30f78e08852907ec2905289a4d2e3d59c9d57bf4097c',
#   'total_amount': 15.9,
#   'inputs': [{'address': '18sCYsXKsZ7WdFZ297BZh3EsKXoz5n6LbF',
#     'amount': Decimal('15.90000000'),
#     'time': 1299380693}],
#   'outputs': [{'address': '1NGfZGjhViztZepTppBqeqBTBPgHJK7M4k',
#     'amount': Decimal('5.40000000'),
#     'time': 1299380693},
#    {'address': '1DrMzNMP7FpfTSLmb6UL9JLN3uGuhmKDJK',
#     'amount': Decimal('10.50000000'),
#     'time': 1299380693}]},
#  {'transaction_id': 'e7dc82681df6ac279f2fb8dfe4997954add80f269ff9169e789f3de9ba8559fc',
#   'total_amount': 65.07,
#   'inputs': [{'address': '1MmKEs6y2xwPe29i2FpaGWh1MCn1X14jwS',
#     'amount': Decimal('65.07000000'),
#     'time': 1299380693}],
#   'outputs': [{'address': '1P6tR829eisA9c3WuzonS1t3sYu7Tck1NR',
#     'amount': Decimal('0.05000000'),
#     'time': 1299380693},
#    {'address': '1Bsvue1dThRjuwmb9wCtwpYg8rAfUcUrnJ',
#     'amount': Decimal('65.01000000'),
#     'time': 1299380693}]},
#  {'transaction_id': 'b41980e0878a6bb356878e5edf82ace8f9942bacd06d5d5ac1d6c80cd2be6dbe',
#   'total_amount': 65.01,
#   'inputs': [{'address': '1Bsvue1dThRjuwmb9wCtwpYg8rAfUcUrnJ',
#     'amount': Decimal('65.01000000'),
#     'time': 1299380693}],
#   'outputs': [{'address': '1B1V4Z7ZjuNKF47TV73AEe66jLv8GNgSkB',
#     'amount': Decimal('64.95000000'),
#     'time': 1299380693},
#    {'address': '114v1GDjjSsiqxCsLrcvaVCByBZLTp4xJx',
#     'amount': Decimal('0.05000000'),
#     'time': 1299380693}]},
#  {'transaction_id': '1f99efc5718e87f55ab447f1318ff78eebe0e7f59e8f55aeca9dbfb96d981f9b',
#   'total_amount': 24.06000001,
#   'inputs': [{'address': '17t3uKR7gKQ5yM3zutyom7zRb9HFsQ6Xgy',
#     'amount': Decimal('24.06000001'),
#     'time': 1299380860}],
#   'outputs': [{'address': '1QB62NnnN9Y2cPgoXJDkEc5nLG9fFoQZPw',
#     'amount': Decimal('24.04000001'),
#     'time': 1299380860},
#    {'address': '1ETm1c2YwWZKTA4o3Xf9iDZ5ZAjZ8xSey7',
#     'amount': Decimal('0.02000000'),
#     'time': 1299380860}]},
#  {'transaction_id': 'b63802d0b09d1a356ed827d2b93a1702e558266d023bcbd2d0a147585e67aa7a',
#   'total_amount': 64.95,
#   'inputs': [{'address': '1B1V4Z7ZjuNKF47TV73AEe66jLv8GNgSkB',
#     'amount': Decimal('64.95000000'),
#     'time': 1299380860}],
#   'outputs': [{'address': '1M7G7J7u6U6suVAkEjVD1sEaJr8LAVYvr1',
#     'amount': Decimal('0.05000000'),
#     'time': 1299380860},
#    {'address': '1MLukQ9ggeh9z2bkfpyppmgnzvZZz6nt4C',
#     'amount': Decimal('64.89000000'),
#     'time': 1299380860}]},
#  {'transaction_id': '00d25e16a478b1fa21e9361ee700470427753f98e06d9ff26e6256be5bb7de2f',
#   'total_amount': 4.21,
#   'inputs': [{'address': '1A5HdyoqxP9gy6c98apdESBaQkUEiUyDGU',
#     'amount': Decimal('4.21000000'),
#     'time': 1299380860}],
#   'outputs': [{'address': '1E36Ws31aptSPsBqvc4FpEqCB5d2NQ5aKn',
#     'amount': Decimal('0.36000000'),
#     'time': 1299380860},
#    {'address': '17nA1EzaGStCjMDcu6GmXtcFmUGKwvYLAG',
#     'amount': Decimal('3.85000000'),
#     'time': 1299380860}]},
#  {'transaction_id': '43e9a788193f53cb58f7567b2389d07529d534d71b5e9331a588caa51eee9237',
#   'total_amount': 0.08,
#   'inputs': [{'address': '16fEVpA6JXnmFuthDz3uk35F9pjAR7TKo4',
#     'amount': Decimal('0.08000000'),
#     'time': 1299380860}],
#   'outputs': [{'address': '19Uie1qPLxMAHRtXz75ptEox8nN93Z95Yb',
#     'amount': Decimal('0.05000000'),
#     'time': 1299380860},
#    {'address': '1T52mcVW3zf7oUyxw1GMmta8KzziYB3kP',
#     'amount': Decimal('0.03000000'),
#     'time': 1299380860}]},
#  {'transaction_id': '41ddae3dcc946b49c99d61d764b166fe886905deacc2fa2e920702f50774acb9',
#   'total_amount': 0.04,
#   'inputs': [{'address': '1DCS4bZUNR5L2pTekD3358RFAft7XYfPtt',
#     'amount': Decimal('0.01000000'),
#     'time': 1299380860},
#    {'address': '1T52mcVW3zf7oUyxw1GMmta8KzziYB3kP',
#     'amount': Decimal('0.03000000'),
#     'time': 1299380860}],
#   'outputs': [{'address': '19Uie1qPLxMAHRtXz75ptEox8nN93Z95Yb',
#     'amount': Decimal('0.04000000'),
#     'time': 1299380860}]},
#  {'transaction_id': '10652f6af49da3eeac3efe5fd25bb6aec19e8b32f66aa7b18d630ed2a3c6d909',
#   'total_amount': 3.85,
#   'inputs': [{'address': '17nA1EzaGStCjMDcu6GmXtcFmUGKwvYLAG',
#     'amount': Decimal('3.85000000'),
#     'time': 1299380860}],
#   'outputs': [{'address': '1ZhKkzRLLfpNGNHf8qDDH7uRZtaMue7tR',
#     'amount': Decimal('0.32000000'),
#     'time': 1299380860},
#    {'address': '1FugT7fzuwKsKjNxyniYsq3WFUK2MEgECP',
#     'amount': Decimal('3.53000000'),
#     'time': 1299380860}]},
#  {'transaction_id': '547c5661353499a30ee4368091ecbaf03ad20f4b07b588cc253e046d809cee46',
#   'total_amount': 3.53,
#   'inputs': [{'address': '1FugT7fzuwKsKjNxyniYsq3WFUK2MEgECP',
#     'amount': Decimal('3.53000000'),
#     'time': 1299380860}],
#   'outputs': [{'address': '131HQdi1o1PvnVcmaKzoeF4xsfmYvhP6tX',
#     'amount': Decimal('3.35000000'),
#     'time': 1299380860},
#    {'address': '17PSyYGLGQj7okX3Aj6cWDXRoxqwD4cByA',
#     'amount': Decimal('0.18000000'),
#     'time': 1299380860}]},
#  {'transaction_id': '33ed61d7bab15fefbf15b3f98296c09c86b53649b7e30f7714646fb6c3264b2c',
#   'total_amount': 3.35,
#   'inputs': [{'address': '131HQdi1o1PvnVcmaKzoeF4xsfmYvhP6tX',
#     'amount': Decimal('3.35000000'),
#     'time': 1299380860}],
#   'outputs': [{'address': '1MtzLXwa3pZKD6MFmXSmV891V6KTQvy2Dt',
#     'amount': Decimal('0.15000000'),
#     'time': 1299380860},
#    {'address': '1KdgqasfmB8Ep6x2TFktZchDbTus7KDL6g',
#     'amount': Decimal('3.20000000'),
#     'time': 1299380860}]},
#  {'transaction_id': '31e994b972c7956cc0055c5a7cf7390ed557262046c4aaa70f0bfe3eed1a2b59',
#   'total_amount': 3.2,
#   'inputs': [{'address': '1KdgqasfmB8Ep6x2TFktZchDbTus7KDL6g',
#     'amount': Decimal('3.20000000'),
#     'time': 1299380860}],
#   'outputs': [{'address': '1EhGrfeCgGzpNi7nLBHYuDyDk6y8quioGR',
#     'amount': Decimal('0.07000000'),
#     'time': 1299380860},
#    {'address': '19RTjtrx2ChotV8dURDoQfnbn62s66apLg',
#     'amount': Decimal('3.13000000'),
#     'time': 1299380860}]},
#  {'transaction_id': '9f70a77d86a7e65e4c33dfeafe5e5560940a2577bcf777474ebe8077d95eb027',
#   'total_amount': 3.13,
#   'inputs': [{'address': '19RTjtrx2ChotV8dURDoQfnbn62s66apLg',
#     'amount': Decimal('3.13000000'),
#     'time': 1299380860}],
#   'outputs': [{'address': '1BYydrz9Qhgt5ANYQWuMoTZMcqbfyUq3HG',
#     'amount': Decimal('3.08000000'),
#     'time': 1299380860},
#    {'address': '1NBG8sqSh632Fa81HRm39tsMEvmgpU9rgZ',
#     'amount': Decimal('0.05000000'),
#     'time': 1299380860}]},
#  {'transaction_id': 'd6b8fc2ce0cc5edf4ba49fea017deb500418910aae3a7a307332d13b1719cbb1',
#   'total_amount': 3.08,
#   'inputs': [{'address': '1BYydrz9Qhgt5ANYQWuMoTZMcqbfyUq3HG',
#     'amount': Decimal('3.08000000'),
#     'time': 1299380860}],
#   'outputs': [{'address': '1FHRwG4gxbQgTegUzdtEvV8zryB91q7aKG',
#     'amount': Decimal('0.02000000'),
#     'time': 1299380860},
#    {'address': '19ac5uDsR433cwzGRiHEp9m7tWD6wxmzDP',
#     'amount': Decimal('3.06000000'),
#     'time': 1299380860}]},
#  {'transaction_id': 'b79c65e816045461eb186e784dcbfb511463f2c0b12114159b01e111e6260c98',
#   'total_amount': 0.05,
#   'inputs': [{'address': '1PUBccyCdFiKU2dArpP9MAYdH4vAd11Zbe',
#     'amount': Decimal('0.05000000'),
#     'time': 1299380996}],
#   'outputs': [{'address': '14Z1mazY4HfysZyMaKudFr63EwHqQT2njz',
#     'amount': Decimal('0.01000000'),
#     'time': 1299380996},
#    {'address': '1K6YHDEvWfiGMfw8nwcS61ouji5aAZVtdB',
#     'amount': Decimal('0.04000000'),
#     'time': 1299380996}]},
#  {'transaction_id': 'cbfe46a979d13de7c2e9dd45e3fe36f0ffc242a4c90b0dd3b289220f9f3afe8b',
#   'total_amount': 3.06,
#   'inputs': [{'address': '19ac5uDsR433cwzGRiHEp9m7tWD6wxmzDP',
#     'amount': Decimal('3.06000000'),
#     'time': 1299380996}],
#   'outputs': [{'address': '1LVndDxUHXAeH6bQ3j7jdvqmZW31kVLT4z',
#     'amount': Decimal('0.01000000'),
#     'time': 1299380996},
#    {'address': '1BdVZ225Xwx7xuceaRU2iNA1oLuh8gMdGE',
#     'amount': Decimal('3.05000000'),
#     'time': 1299380996}]},
#  {'transaction_id': 'c3bf8728a5e03c38568a6d6b3dadf60b84f52590d0b92e89f43acb41f3a32719',
#   'total_amount': 3.05,
#   'inputs': [{'address': '1BdVZ225Xwx7xuceaRU2iNA1oLuh8gMdGE',
#     'amount': Decimal('3.05000000'),
#     'time': 1299380996}],
#   'outputs': [{'address': '1NyP41wRAq2hbmMCwfvZ4kuFuLqEvpf2WE',
#     'amount': Decimal('0.01000000'),
#     'time': 1299380996},
#    {'address': '1Au4Y66BvMCMrYwj7AbabjSppJd4mvbV5v',
#     'amount': Decimal('3.04000000'),
#     'time': 1299380996}]},
#  {'transaction_id': '9d31d218f66836603cd58886a1e53575fcca94a848d7a4746f65b36e1326d6de',
#   'total_amount': 3.04,
#   'inputs': [{'address': '1Au4Y66BvMCMrYwj7AbabjSppJd4mvbV5v',
#     'amount': Decimal('3.04000000'),
#     'time': 1299380996}],
#   'outputs': [{'address': '1LnpkHmrGvrcmrCncCkiVraov6Mm9BuAXm',
#     'amount': Decimal('0.01000000'),
#     'time': 1299380996},
#    {'address': '1MssQqK8MpUVVbN7f9Y3sdE27K1Qa55KRF',
#     'amount': Decimal('3.03000000'),
#     'time': 1299380996}]},
#  {'transaction_id': 'e168ba71490afc5c0d43dcaf6210d549ce37ba8165cd316c415189ed5bb0dd30',
#   'total_amount': 0.04,
#   'inputs': [{'address': '17ZiL685Ji52Q6ZLhJXet83Gmjz59fRQDN',
#     'amount': Decimal('0.04000000'),
#     'time': 1299381306}],
#   'outputs': [{'address': '1PuThtepnQ2thn86NPC5HnaWoAShLm7Zm',
#     'amount': Decimal('0.03000000'),
#     'time': 1299381306},
#    {'address': '16DUazgNwpoTaSRpCSKbMdVH7aND3h29jq',
#     'amount': Decimal('0.01000000'),
#     'time': 1299381306}]},
#  {'transaction_id': '3594cf8f5656a68c09c250d1c8861a0c4afcb81b4b290eccf33336a77a92786f',
#   'total_amount': 0.05,
#   'inputs': [{'address': '1DkS9KCSUxZSjpmb64HRJHkLQ9WfgsKQvL',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381419}],
#   'outputs': [{'address': '129XnNNhe7LcX9gt4hpKPvc2z6NNFtHjgQ',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381419}]},
#  {'transaction_id': 'c49c911991cb3244c6501147e3c611a2faeea951fbcbe4273a51d9500016315f',
#   'total_amount': 37790.42,
#   'inputs': [{'address': '1748UZ1VXeFqSp8qFXdGB3PM8nz5zjbqRY',
#     'amount': Decimal('37790.42000000'),
#     'time': 1299381659}],
#   'outputs': [{'address': '171utvtF4SVkgNR7VXqht5dZStn7UvJ5wL',
#     'amount': Decimal('37290.42000000'),
#     'time': 1299381659},
#    {'address': '1NQkzExhgXjwL7pJuiQn2HrKkySdSznme5',
#     'amount': Decimal('500.00000000'),
#     'time': 1299381659}]},
#  {'transaction_id': '21f96a72a48abf41484fe748068bc2746b5bcb3bcddadc2c5736f6a2ac30b990',
#   'total_amount': 64.89,
#   'inputs': [{'address': '1MLukQ9ggeh9z2bkfpyppmgnzvZZz6nt4C',
#     'amount': Decimal('64.89000000'),
#     'time': 1299381676}],
#   'outputs': [{'address': '12UTb4NUsKGAgtNoTsTjPGDgBonXrfbmsw',
#     'amount': Decimal('64.83000000'),
#     'time': 1299381676},
#    {'address': '1BCpRyCWgey342tTB59yws3ADZwpkxrvJR',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381676}]},
#  {'transaction_id': '9a54da5afe31d4270b43168114cd984dbeb5634b049c3242df02168cc08bd1fd',
#   'total_amount': 19.699999999999996,
#   'inputs': [{'address': '1NwABM9V6iNTcYXqwQvgFM68zQeUST9wGy',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381676},
#    {'address': '13FW27uYdh1nLLUXpYzu8cQT8MdybxqM61',
#     'amount': Decimal('1.40000000'),
#     'time': 1299381676},
#    {'address': '12vtPrukGVpeovQjmqTTviFpiEe7jKNJpq',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381676},
#    {'address': '1BxTtMNYKKTVnxT1qnuy15Mh7hqj9YMky3',
#     'amount': Decimal('0.01000000'),
#     'time': 1299381676},
#    {'address': '1NbLPvDEvpcbKXKoAukwMaoXKJeDgRpbyy',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381676},
#    {'address': '1MCwBbhNGp5hRm5rC1Aims2YFRe2SXPYKt',
#     'amount': Decimal('0.04000000'),
#     'time': 1299381676},
#    {'address': '1NbLPvDEvpcbKXKoAukwMaoXKJeDgRpbyy',
#     'amount': Decimal('0.02000000'),
#     'time': 1299381676},
#    {'address': '1dVgxTGy8STEBtyRFbojY7dLN8KQ7mnnv',
#     'amount': Decimal('0.15000000'),
#     'time': 1299381676},
#    {'address': '126bMAWKb9JPt4Rc1gTvtoF9bew1SA8Uzm',
#     'amount': Decimal('0.14000000'),
#     'time': 1299381676},
#    {'address': '1DYaEZFN6JsSvsjnnsgYCvpwqog1XHDEi4',
#     'amount': Decimal('1.06000000'),
#     'time': 1299381676},
#    {'address': '15ebPYBixt8C45QeHAZKxYh6g5uPmcqwRb',
#     'amount': Decimal('0.50000000'),
#     'time': 1299381676},
#    {'address': '1NbLPvDEvpcbKXKoAukwMaoXKJeDgRpbyy',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381676},
#    {'address': '1NbLPvDEvpcbKXKoAukwMaoXKJeDgRpbyy',
#     'amount': Decimal('0.04000000'),
#     'time': 1299381676},
#    {'address': '1ETFxV4YFCenaTVqUyWhudryjuNS3Ca2qb',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381676},
#    {'address': '1dVgxTGy8STEBtyRFbojY7dLN8KQ7mnnv',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381676},
#    {'address': '1HZYXDYDqyiaJBMveo6G9QGbYXuv8RRjv6',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381676},
#    {'address': '126bMAWKb9JPt4Rc1gTvtoF9bew1SA8Uzm',
#     'amount': Decimal('0.37000000'),
#     'time': 1299381676},
#    {'address': '1dVgxTGy8STEBtyRFbojY7dLN8KQ7mnnv',
#     'amount': Decimal('0.10000000'),
#     'time': 1299381676},
#    {'address': '13FW27uYdh1nLLUXpYzu8cQT8MdybxqM61',
#     'amount': Decimal('1.50000000'),
#     'time': 1299381676},
#    {'address': '16cWgfTEY2Nvda4A5hsbGg7vC42qMQ3iMt',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381676},
#    {'address': '1FA2rVYzuQ4HFKgDw6Tmbig8WWVhYbUVc3',
#     'amount': Decimal('0.41000000'),
#     'time': 1299381676},
#    {'address': '13U56zncvzmXFySZZgaQJSuzwEHeZJGwkG',
#     'amount': Decimal('1.02000000'),
#     'time': 1299381676},
#    {'address': '1NyUv5NUQpkgPj2rkp99t1Z5ED2LZp6Zt9',
#     'amount': Decimal('10.44000000'),
#     'time': 1299381676},
#    {'address': '1BTJhAJN7E74ny7qP9rUw4MEiEuhLfoVmE',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381676},
#    {'address': '1NEEFwHjXDhbLZ2RxM6qSDnNDByNZYCSKf',
#     'amount': Decimal('1.06000000'),
#     'time': 1299381676},
#    {'address': '1dVgxTGy8STEBtyRFbojY7dLN8KQ7mnnv',
#     'amount': Decimal('0.20000000'),
#     'time': 1299381676},
#    {'address': '1KvSeTLHNfG64rWSWgxAtbsNdnyMWmmRrY',
#     'amount': Decimal('0.79000000'),
#     'time': 1299381676}],
#   'outputs': [{'address': '1N5sJucDyY6F8riFpJeCDsGHfcCG7Cf6uX',
#     'amount': Decimal('19.70000000'),
#     'time': 1299381676}]},
#  {'transaction_id': '0dde30f1f9a3756dc6daf7c0474d201fc11b82435466fa45b3bf3b9476adb2de',
#   'total_amount': 64.83,
#   'inputs': [{'address': '12UTb4NUsKGAgtNoTsTjPGDgBonXrfbmsw',
#     'amount': Decimal('64.83000000'),
#     'time': 1299381774}],
#   'outputs': [{'address': '1H4vmBtDNusGpxWXSbjQGrpqVpiEcgXWMS',
#     'amount': Decimal('0.05000000'),
#     'time': 1299381774},
#    {'address': '14G1KuveqHCTfD9SgdRocVvQqGfHU991F9',
#     'amount': Decimal('64.77000000'),
#     'time': 1299381774}]},
#  {'transaction_id': '20d15970397433c886c0d017e09e719d42edb2467e0298f0ee03b0661cf2283f',
#   'total_amount': 24.04000001,
#   'inputs': [{'address': '1QB62NnnN9Y2cPgoXJDkEc5nLG9fFoQZPw',
#     'amount': Decimal('24.04000001'),
#     'time': 1299382266}],
#   'outputs': [{'address': '19ErF4JR8YK5DsvQuoVNXXSTvNWp8vZq2K',
#     'amount': Decimal('23.14000001'),
#     'time': 1299382266},
#    {'address': '14cUZX16iAQ7c9ZikpNfGmDuVfWGeRUoP3',
#     'amount': Decimal('0.90000000'),
#     'time': 1299382266}]},
#  ...]

# %%
df
# Out:
#                                                       tx  \
# 0      69bfa9995a2e587e6b16e3d0292b79f5ab0cfe50ceb1bf...
# 1      23c6e93f53b42de620ea663b151c9651802cc9dbf30f57...
# 2      846067070c45b8de8e30b676dd8491accb6a4987e629d8...
# 3      19f4273b6d5bed678a6a8a225ec8b16838428e7a785a20...
# 4      a82882d74e52a7f2c99fde01e3c667854f9c8fb6b3632c...
# ...                                                  ...
# 88488  8886e13c7c0f186ab5cf90bee0a585934e42fde805720d...
# 88489  6b7941d4ed25205ca1d7d5816bcf0125f1cd1860d5c363...
# 88490  6b7941d4ed25205ca1d7d5816bcf0125f1cd1860d5c363...
# 88491  2820aee05bd4cf8cb9120386c54dc21c2ef895d3e881cf...
# 88492  2820aee05bd4cf8cb9120386c54dc21c2ef895d3e881cf...
#
#                                address_in  input_pos     value_in        time  \
# 0      15mbsahyyG8UUPeX8BgAzntXgbbpDSCvKd        0.0   6.00000000  1299335141
# 1      1CAmvuizVuANavWSvAYqxypfTKFxz2cSPg        0.0  79.29000000  1299335141
# 2      16KADGbf7Lna9T3ohk8rGw5V418Xqv3krh        0.0  79.23000000  1299335141
# 3      19zzW2b2odPWPmX8m4Y3zgakUWHEEUf5Kk        0.0  79.17000000  1299335141
# 4      19HY4dPZVLepSSviawjRbBwYiP329HnvpX        0.0  79.11000000  1299335141
# ...                                   ...        ...          ...         ...
# 88488                                None        NaN         None  1300441137
# 88489                                None        NaN         None  1300441137
# 88490                                None        NaN         None  1300441137
# 88491                                None        NaN         None  1300441137
# 88492                                None        NaN         None  1300441137
#
#                               address_out  output_pos   value_out
# 0                                    None         NaN        None
# 1                                    None         NaN        None
# 2                                    None         NaN        None
# 3                                    None         NaN        None
# 4                                    None         NaN        None
# ...                                   ...         ...         ...
# 88488  1MwKBcSCE1gQaCmK3wADPdQdMz37VB21cf         1.0  3.81000000
# 88489  1NhDsbzw61UETUArd2oGDZS6nsFuBopdb8         0.0  0.18000000
# 88490  19FSMkQBcqaLFJ1aX8YgyZxA91FhBCNkSB         1.0  2.25000000
# 88491  1CK4JK9uVw5oum2P2CqXBiKjDRZiTChQ5t         0.0  2.27000000
# 88492  18n7j3D2nTbojv6m2rXbh7DmTBWzHyLwWw         1.0  0.25000000
#
# [88493 rows x 8 columns]

# %%
result = write_to_neo(session, addresses, transactions)
if result:
    print ("Blocks written to neo4j")
else: 
    print ("there occured an error in writing to neo4j db")
# Out:
# Blocks written to neo4j

# %% [markdown]
# ##### Useful NEO4J Snippets

# %% [markdown]
# MATCH (n)
# DETACH DELETE n
#
#
#
# RETURN datetime({epochSeconds: 1299336076000 / 1000}) AS theDate
#
#
#
# MATCH (s:Address {address: '1918yyUX3HEftoWZHq9qgKxWPQmCecCtJY'}), (t:Address {address: '1Jfz35JognNZRLAKbp8BnCuUWMmExQotf7'})
# MATCH path = shortestPath((s)-[:TRANSACTION_OUTPUT|TRANSACTION_INPUT*1..10]-(t))
# RETURN path
#
#
#
# 13MfK8Wsxz1eoZLBrYUShxZ29NtT3XNWSA
# 1EpEE1rp1nWqo6YP53w7rFgPbCZj1wCXL8
#
# address: 1918yyUX3HEftoWZHq9qgKxWPQmCecCtJY
# address: 1Jfz35JognNZRLAKbp8BnCuUWMmExQotf7
